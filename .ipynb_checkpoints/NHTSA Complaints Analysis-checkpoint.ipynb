# %% [markdown]
# # NHTSA Complaints Analysis
#
# In this notebook, we'll showcase the analytical tools from NHTSAComplaints.py
#
# ## Table of Contents
# 1. The ```Vehicle``` and ```VehicleList``` Classes
# * Methods for Vehicles and VehicleLists
# 2. Sample Analysis
# * Chevy Cobalt Power Steering
# * 2009-2011 Toyota Recalls

# %%
from NHTSAComplaints import *
sns.set(rc={'axes.facecolor':'white', 'figure.facecolor':'white'})

# %% [markdown]
# ## 1. The Vehicle and VehicleList Classes

# %% [markdown]
# We can specify a single vehicle with a year, make and model. For example, we'll define a 2006 Chevy Cobalt:

# %%
v = Vehicle(2012,'ford','focus')
print(v)
# Out:
# 2012 FORD FOCUS

# %% [markdown]
# If we are unsure about the specific names of a make or model, there are several helper functions available. For example, to get a list of makes for a certain year, we can call ```get_makes(year)```:

# %%
print( get_makes(2012) )
# Out:
# ['4-STAR', 'ACURA', 'AMERIVAN', 'APRILIA', 'ARISING', 'ASTON MARTIN', 'AUDI', 'BAD BOY', 'BENTLEY', 'BIG TEX', 'BLUE BIRD', 'BMW', 'BOATMATE', 'BRAUNABILITY', 'BUICK', 'CADILLAC', 'CAN-AM', 'CARRIAGE', 'CEDAR CREEK', 'CHAMPION', 'CHEROKEE', 'CHEVROLET', 'CHRYSLER', 'CLUB CAR', 'COACHMEN', 'CODA', 'COLEMAN', 'CONTINENTAL CARGO', 'CROSSROADS', 'CRUISER RV', 'DENALI', 'DODGE', 'DRV', 'DUCATI', 'DUTCHMEN', 'ECLIPSE', 'ENTEGRA', 'EZ LOADER', 'FCCC', 'FEATHERLITE', 'FERRARI', 'FIAT', 'FISKER', 'FLEETWOOD', 'FORD', 'FOREST RIVER', 'FOUR WHEEL & SIX-PAC', 'FOUR WINDS', 'FOURWINDS', 'FREIGHTLINER', 'GMC', 'GULF STREAM', 'HARLEY-DAVIDSON', 'HAUL MASTER', 'HEARTLAND', 'HOLIDAY RAMBLER', 'HONDA', 'HYUNDAI', 'IC', 'IC BUS', 'INFINITI', 'INTERNATIONAL', 'INTERSTATE', 'ISUZU', 'ITASCA', 'JAGUAR', 'JAYCO', 'JAYCO FIFTH WHEEL', 'JAYCO TRAVEL TRAILER', 'JEEP', 'K-Z', 'KARAVAN', 'KAWASAKI', 'KENWORTH', 'KEYSTONE', 'KIA', 'KME', 'KOMFORT', 'KTM', 'KYMCO', 'KZRV', 'LAND ROVER', 'LEXUS', 'LINCOLN', 'LITTLE GUY', 'LOAD MAX', 'LOTUS', 'MASERATI', 'MAZDA', 'MCI', 'MCLAREN', 'MERCEDES BENZ', 'MERCEDES-BENZ', 'MERCURY', 'MINI', 'MITSUBISHI', 'MITSUBISHI FUSO', 'MONACO', 'MOTO GUZZI', 'MV AGUSTA', 'MV-1', 'NEW FLYER', 'NEWMAR', 'NEXUS', 'NISSAN', 'NORTHWOOD', 'OPEN RANGE', 'PALOMINO', 'PETERBILT', 'PIAGGIO', 'PIAGGIO AND VESPA', 'POLARIS', 'PORSCHE', 'PRIME TIME', 'RAM', 'ROAD KING', 'ROADTREK', 'SCION', 'SEA-DOO', 'SKYLINE', 'SMART', 'SOUTHERN VAC', 'SPARTAN', 'STARCRAFT', 'SUBARU', 'SUNNYBROOK', 'SUZUKI', 'SYM', 'TESLA', 'TEXAS BRAGG', 'THOMAS BUILT BUSES', 'THOR', 'TIFFIN', 'TOYOTA', 'TRAILS WEST', 'TRAILSTAR', 'TRIUMPH', 'URAL', 'UTILITY', 'VENTURE', 'VICTORY', 'VIKING CAMPING TRAILER', 'VINTAGE', 'VOLKSWAGEN', 'VOLVO', 'WESTERN STAR', 'WILDFIRE', 'WIND RIVER', 'WINNEBAGO', 'YAMAHA', 'ZERO']

# %% [markdown]
# For a list of models of a given make and year, we can call ```get_models(make, year)```:

# %%
print( get_models('ford',2012) )
# Out:
# ['E-150', 'E-250', 'E-350', 'E-450', 'EDGE', 'ESCAPE', 'ESCAPE HYBRID', 'EXPEDITION', 'EXPLORER', 'F-150', 'F-250', 'F-250 SD', 'F-350', 'F-350 SD', 'F-350 SUPER DUTY', 'F-450', 'F-450 SD', 'F-53', 'F-550', 'F-550 SD', 'F-650', 'FIESTA', 'FLEX', 'FOCUS', 'FOCUS ELECTRIC', 'FUSION', 'FUSION ENERGI', 'FUSION HYBRID', 'MUSTANG', 'POLICE INTERCEPTOR UTILIT', 'TAURUS', 'TRANSIT CONNECT']

# %% [markdown]
# There are several methods associated to the vehicle class. They are (currently):
# - ```.get_complaint_df()``` - This method returns a dataframe of complaints about the vehicle from the NHTSA.
# - ```.get_recall_df()``` - This method returns a dataframe of recalls featuring the vehicle from the NHTSA.
# - ```.comp_per_month(endyear, component, datetype)``` - This method produces a bar plot of complaints per month until the endyear for a specified vehicle component. Here, datetype specifies either:
#     - ```datetype='recieved'``` - the date the NHTSA recieved the complaint
#     - ```datetype='incident'``` - the date the incident was reported to have occurred.

# %%
# example of the complaint dataframe for the 2012 Ford Focus
df = v.get_complaint_df()
df.head()
# Out:
#      ODI_ID            MFR_NAME CRASH_YN FIRE_YN  NUM_INJURED  NUM_DEATHS  \
# 0  10453300  Ford Motor Company       No      No            0           0
# 1  10759100  Ford Motor Company       No      No            0           0
# 2  10726900  Ford Motor Company       No      No            0           0
# 3  10731800  Ford Motor Company       No      No            0           0
# 4  10606600  Ford Motor Company       No      No            0           0
#
#   INCIDENT_DT              RECVD_DT          VIN                  COMPONENT  \
# 0  2012-02-17            2012-03-28          NaN  ENGINE AND ENGINE COOLING
# 1  2015-08-20  2015-08-25T15:03:04Z          NaN             STRUCTURE:BODY
# 2  2013-08-14            2015-06-23  1FAHP3H22CL                   STEERING
# 3  2015-07-02  2015-07-02T21:00:52Z          NaN                POWER TRAIN
# 4  2012-08-23            2014-06-27  1FAHP3K20CL                POWER TRAIN
#
#                                                DESCR PRODUCT_TYPE  MODEL_YR  \
# 0  JUST A FEW DAYS AFTER WE BOUGHT THIS CAR, I WA...      VEHICLE      2012
# 1  MY 2012 FORD FOCUS HAS A FAULTY BACK DRIVER SI...      VEHICLE      2012
# 2  TL* THE CONTACT OWNS A 2012 FORD FOCUS. WHILE ...      VEHICLE      2012
# 3  WHILE ACCELERATING AND MERGING ONTO THE INTERS...      VEHICLE      2012
# 4  THE TRANSMISSION IS OFF. I HAVE TAKEN IT 4 TIM...      VEHICLE      2012
#
#    MAKE  MODEL
# 0  FORD  FOCUS
# 1  FORD  FOCUS
# 2  FORD  FOCUS
# 3  FORD  FOCUS
# 4  FORD  FOCUS

# %%
# example of the recall dataframe for the 2012 Ford Focus
rec = v.get_recall_df()
rec.head()
# Out:
#    BEGMAN_DT  ENDMAN_DT                 MFGTXT     CAMPNO ACTION_NUMBER  \
# 0        NaN        NaN     Ford Motor Company  20V331000       RQ19005
# 1        NaN        NaN  YAKIMA PRODUCTS, INC.  12E035000           NaN
# 2        NaN        NaN     FORD MOTOR COMPANY  12V149000           NaN
# 3        NaN        NaN     Ford Motor Company  13V335000           NaN
# 4        NaN        NaN     Ford Motor Company  16V643000       PE16001
#
#   REPORT_DATE                                         COMPONENT  POTAFF  \
# 0  2020-06-08                LATCHES/LOCKS/LINKAGES:DOORS:LATCH     NaN
# 1  2012-10-02                                         EQUIPMENT     NaN
# 2  2012-04-05  VISIBILITY:WINDSHIELD WIPER/WASHER:SWITCH/WIRING     NaN
# 3  2013-08-01                                 EXTERIOR LIGHTING     NaN
# 4  2016-09-06                LATCHES/LOCKS/LINKAGES:DOORS:LATCH     NaN
#
#                                         DESCR_DEFECT  \
# 0  Ford Motor Company (Ford) is recalling certain...
# 1  This recall involves aftermarket parts sold by...
# 2  FORD IS RECALLING CERTAIN MODEL YEAR 2012 FOCU...
# 3  Ford is recalling certain model year 2012-2013...
# 4  Ford Motor Company (Ford) is recalling certain...
#
#                                   CONSEQUENCE_DEFECT  \
# 0  A door that is not securely latched could open...
# 1  Without proper contact of the rooftop rack cli...
# 2  WATER OR OTHER CONTAMINANTS MAY ACCUMULATE IN ...
# 3  Without the proper illumination of the side ma...
# 4  A door that is not securely latched could open...
#
#                                    CORRECTIVE_ACTION  \
# 0  Ford will notify owners, and dealers will insp...
# 1  Yakima will notify owners, and Yakima or a Yak...
# 2  FORD WILL NOTIFY OWNERS, AND DEALERS WILL INSP...
# 3  Ford will notify owners, and dealers will modi...
# 4  Ford will notify owners, and dealers will repl...
#
#                                                NOTES  PRODUCT_TYPE  MODEL_YR  \
# 0  Owners may also contact the National Highway T...           NaN      2012
# 1  Owners may also contact the National Highway T...           NaN      2012
# 2  FORD'S SAFETY RECALL CAMPAIGN NUMBER IS 12S29....           NaN      2012
# 3  Owners may also contact the National Highway T...           NaN      2012
# 4  Owners may also contact the National Highway T...           NaN      2012
#
#    MAKE  MODEL
# 0  FORD  FOCUS
# 1  FORD  FOCUS
# 2  FORD  FOCUS
# 3  FORD  FOCUS
# 4  FORD  FOCUS

# %%
# complaints per month for the steering components
v.comp_per_month(2016, 'POWER TRAIN', 'incident')

# %% [markdown]
# It is common for component issues to persist through 2 or more production years. This motivates the ```VehicleList``` class, which has methods for comparing issues across multiple production years or multiple models.

# %%
v_list = VehicleList([Vehicle(2006, 'chevrolet', 'cobalt'), Vehicle(2007, 'chevrolet', 'cobalt'), Vehicle(2008, 'chevrolet', 'cobalt')])
print(v_list)
# Out:
# ['2006 CHEVROLET COBALT', '2007 CHEVROLET COBALT', '2008 CHEVROLET COBALT']

# %% [markdown]
# There are several methods associated to the ```VehicleList``` class. They are (currently):
# - ```.get_complaints()``` - This method produces a dictionary of complaint dataframes of the form ```{Vehicle : DataFrame of complaints}```
# - ```.get_recalls()``` - This method produces a dictionary of recall dataframes of the form ```{Vehicle : DataFrame of recalls}```
# - ```.component_parts(keyword)``` - This method produces a list of components mentioned in the complaint data. Here, ```keyword``` can take the values:
#     - ```keyword='ALL'``` - produces a list of all components featured
#     - ```keyword='STEERING'``` - (for example) this returns a list of subcomponents in the "steering" category.
# - ```.create_heatmap(keyword, value)``` - This method produces a heatmap displaying how many complaints were received for each component. The ```keyword``` parameter is as above, and the ```value``` parameter can take the values ```complaints, fires, injuries, crashes, or deaths```.

# %% [markdown]
# ## 2. Sample Analysis

# %% [markdown]
# ### Chevy Cobalt
#
# * https://www.autoblog.com/2010/03/02/gm-recalls-1-3-million-cobalts-g5s-for-power-steering-problem/

# %%
cobalts_05_10 = VehicleList([Vehicle(i, 'chevrolet', 'cobalt') for i in range(2005,2010)])
cobalts_05_10.create_heatmap('ALL', 'complaints')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 cobalts_05_10 = VehicleList([Vehicle(i, 'chevrolet', 'cobalt') for i in range(2005,2010)])
# ----> 2 cobalts_05_10.create_heatmap('ALL', 'complaints')
#
# File ~/NHTSA-complaints/NHTSAComplaints.py:206, in VehicleList.create_heatmap(self, keyword, value, air_bags)
#     202 	print('"complaints", "fires", "crashes", "injuries", or "deaths"')
#     204 	return
# --> 206 data = self.get_complaints()
#     207 components = self.component_parts(keyword)
#     208 total_data={}
#
# File ~/NHTSA-complaints/NHTSAComplaints.py:151, in VehicleList.get_complaints(self)
#     149 data = {}
#     150 for i in self.vehicle_list:
# --> 151 	data[i] = i.get_complaint_df()
#     153 return data
#
# TypeError: unhashable type: 'Vehicle'

# %% [markdown]
# Let's dig a bit deeper into the steering issues:

# %%
cobalts_05_10.create_heatmap('STEERING', 'complaints')

# %% [markdown]
# Now let's check if the issue has a recall associated to it:

# %%
recall_dfs = cobalts_05_10.get_recalls()
rec = pd.concat([recall_dfs[key] for key in recall_dfs.keys()])
cobalt_steering = rec[rec['COMPONENT'].str.contains('STEERING')]
cobalt_steering
# Out:
#    BEGMAN_DT  ENDMAN_DT                MFGTXT     CAMPNO ACTION_NUMBER  \
# 2        NaN        NaN  GENERAL MOTORS CORP.  10V073000       PE10005
# 2        NaN        NaN  GENERAL MOTORS CORP.  10V073000       PE10005
# 1        NaN        NaN  GENERAL MOTORS CORP.  10V073000       PE10005
# 0        NaN        NaN  GENERAL MOTORS CORP.  10V073000       PE10005
# 1        NaN        NaN  GENERAL MOTORS CORP.  10V073000       PE10005
#
#   REPORT_DATE                              COMPONENT  POTAFF  \
# 2  2010-03-03  STEERING:ELECTRIC POWER ASSIST SYSTEM     NaN
# 2  2010-03-03  STEERING:ELECTRIC POWER ASSIST SYSTEM     NaN
# 1  2010-03-03  STEERING:ELECTRIC POWER ASSIST SYSTEM     NaN
# 0  2010-03-03  STEERING:ELECTRIC POWER ASSIST SYSTEM     NaN
# 1  2010-03-03  STEERING:ELECTRIC POWER ASSIST SYSTEM     NaN
#
#                                         DESCR_DEFECT  \
# 2  GENERAL MOTORS IS RECALLING CERTAIN MODEL YEAR...
# 2  GENERAL MOTORS IS RECALLING CERTAIN MODEL YEAR...
# 1  GENERAL MOTORS IS RECALLING CERTAIN MODEL YEAR...
# 0  GENERAL MOTORS IS RECALLING CERTAIN MODEL YEAR...
# 1  GENERAL MOTORS IS RECALLING CERTAIN MODEL YEAR...
#
#                                   CONSEQUENCE_DEFECT  \
# 2  IF POWER STEERING ASSIST IS LOST, IT WOULD REQ...
# 2  IF POWER STEERING ASSIST IS LOST, IT WOULD REQ...
# 1  IF POWER STEERING ASSIST IS LOST, IT WOULD REQ...
# 0  IF POWER STEERING ASSIST IS LOST, IT WOULD REQ...
# 1  IF POWER STEERING ASSIST IS LOST, IT WOULD REQ...
#
#                                    CORRECTIVE_ACTION  \
# 2  DEALERS WILL REPLACE THE ELECTRIC POWER STEERI...
# 2  DEALERS WILL REPLACE THE ELECTRIC POWER STEERI...
# 1  DEALERS WILL REPLACE THE ELECTRIC POWER STEERI...
# 0  DEALERS WILL REPLACE THE ELECTRIC POWER STEERI...
# 1  DEALERS WILL REPLACE THE ELECTRIC POWER STEERI...
#
#                                                NOTES  PRODUCT_TYPE  MODEL_YR  \
# 2  GM'S RECALL NO. N100023.  OWNERS MAY ALSO CONT...           NaN      2005
# 2  GM'S RECALL NO. N100023.  OWNERS MAY ALSO CONT...           NaN      2006
# 1  GM'S RECALL NO. N100023.  OWNERS MAY ALSO CONT...           NaN      2007
# 0  GM'S RECALL NO. N100023.  OWNERS MAY ALSO CONT...           NaN      2008
# 1  GM'S RECALL NO. N100023.  OWNERS MAY ALSO CONT...           NaN      2009
#
#         MAKE   MODEL
# 2  CHEVROLET  COBALT
# 2  CHEVROLET  COBALT
# 1  CHEVROLET  COBALT
# 0  CHEVROLET  COBALT
# 1  CHEVROLET  COBALT

# %% [markdown]
# This shows that the recall was issued in early 2010. When did Chevy know about the issue? Let's check the 2005 Cobalt as an example:

# %%
cobalts_05_10.vehicle_list[0].comp_per_month(2011, 'STEERING', 'received')

# %% [markdown]
# ### Beige Bites Back
# As a somewhat well-known example, in the years 2009-2011, Toyota issued a recall of many different models due to accelerator pedals getting stuck.
#
# * https://en.wikipedia.org/w/index.php?title=2009%E2%80%932011_Toyota_vehicle_recalls&oldformat=true#Affected_vehicles_and_vehicle_lines
#
# We can detect this with our heatmap, for a subset of the affected vehicles:

# %%
corollas = [Vehicle(year, 'toyota', 'corolla') for year in range(2009,2011)]
camrys = [Vehicle(year, 'toyota', 'camry') for year in range(2007,2011)]
avalons = [Vehicle(year, 'toyota', 'avalon') for year in range(2005,2010)]
toyota_list = VehicleList(corollas+camrys+avalons)

# %%
toyota_list.create_heatmap('ALL', 'complaints',air_bags=False)

# %% [raw]
# Sure enough, we see that vehicle speed control is a hotspot for complaints for this list of vehicles. Again, we dig a bit deeper:

# %%
toyota_list.create_heatmap('VEHICLE SPEED CONTROL', 'complaints')

# %% [markdown]
# As expected, the main issue is with the accelerator pedals.
